# %%
import pandas as pd
import numpy as np
import datetime 
#data_update
df=pd.read_csv('LPA_dataset.csv')
pd.DataFrame(df.columns)


sns = pd.read_excel('추이분석.xlsx')
sns['날짜'] = sns['날짜'].astype(str)
sns['year'] = sns['날짜'].str[:4]
sns['month']=sns['날짜'].str[4:6]
sns2023 = sns[sns['year'] == '2023']
sns_sgg_mm_avg = sns2023[['SGG_CD','month','전체']].groupby(['SGG_CD', 'month']).sum().reset_index().groupby(['SGG_CD']).mean('전체').reset_index()
sns_sgg_mm_avg.rename(columns = {'전체' : 'sns_mm_avg_cnt', 'SGG_CD':'sgg_cd'}, inplace = True)
df = pd.merge(df,sns_sgg_mm_avg, how='left',on='sgg_cd')

# %%
df['popl_tou_rat'] = df['sgg_tou_num']/df['popl_num_2023_10'] #방문객수/인구수
df['sgg_tou_rat'] = df['sgg_tou_num']/(df['sgg_tou_num'].mean())#방문객 수 / 107곳 평균

df['dstnc_tou_rat'] = df['wgt_rflt_dstnc_tou_num']/df['sgg_tou_num'] #타지역/방문객수
df['frn_tou_rat'] = df['frn_tou_num']/df['sgg_tou_num']
df['tou_srch_rat'] = df['sgg_tou_num']/df['srch_num'] #방문객수/검색건수
df['compt_GRDP_rat'] = df['compt_amt']/df['GRDP'] #카드소비액/지역총생산
df['lodg_comp_rat'] = df['lodg_tob_card_compt_amt']/df['compt_amt']
df['tour_comp_rat'] = df['tour_tob_card_compt_amt']/df['compt_amt']
df['trs_comp_rat'] = df['trs_tob_card_compt_amt']/df['compt_amt']
df['shpn_comp_rat'] = df['shpn_tob_card_compt_amt']/df['compt_amt']
df['sptm_comp_rat'] = df['sptm_svc_tob_rela_card_compt_amt']/df['compt_amt']
df['food_drk_comp_rat'] = df['food_drk_tob_rela_card_compt_amt']/df['compt_amt']

df['tar_num'] = df['natur_tar_num']+df['acad_tar_num']+df['rpts_tar_num']+df['shpn_tar_num']+df['food_tar_num']+df['lodg_tar_num']
df['natur_tar_rat'] = df['natur_tar_num']/df['tar_num'] #자연관광지비율
df['acad_tar_rat'] = df['acad_tar_num']/df['tar_num'] #인문관광지비율
df['rpts_tar_rat'] = df['rpts_tar_num']/df['tar_num'] #레포츠관광지비율
df['shpn_tar_rat'] = df['shpn_tar_num']/df['tar_num'] #쇼핑관광지비율
df['food_tar_rat'] = df['food_tar_num']/df['tar_num'] #음식관광지비율
df['lodg_tar_rat'] = df['lodg_tar_num']/df['tar_num'] #숙박관광지비율
df['biz_turs_rat'] = df['totl_tursm_biz_num']/df['totl_biz_num'] #관광사업체비율
df['biz_tou_num_rat'] = df['totl_tursm_biz_num']/df['sgg_tou_num'] #방문자대비관광사업체
df['tursm_wker_rat'] = df['totl_tursm_biz_wker_num']/df['totl_wker_num'] #관광종사자비율

df['fstv_rat']=df['fstv_num']/df['SGG_CONT_TOU_NUM'] #축제수/방문객수
df['tursm_bdgt_rat']=df['sido_tursm_bdgt_2023']/df['SGG_CONT_TOU_NUM'] #관광예산수/방문객수
df['ct_tour_rat']=df['ct_tour_num']/df['SGG_CONT_TOU_NUM'] #시티투어버스수/방문객수
df['socty_corpo_rat']=df['socty_corpo_num']/df['SGG_CONT_TOU_NUM'] #마을기업수/방문객수	
df['INFO_CNT_RAT']=df['INFO_CNT']/df['SGG_CONT_TOU_NUM'] #안내소수/방문객수	
df['TRAD_COMT_RAT']=df['TRAD_COMT']/df['SGG_CONT_TOU_NUM'] #문화관광해설사수/방문객수
df['CAR_RAT']=df['car_pub_zon_num']/df['SGG_CONT_TOU_NUM'] #카셰어링존수/방문객수
df['frn_tou_rat']=df['frn_tou_num']/df['popl_num_2023_10'] #GRDP/인구수 
df['GRDP_rat']=df['GRDP']/df['popl_num_2023_10'] #GRDP/인구수 

df['visitr_1020_rat'] = df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
df['visitr_3040_rat'] = df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
df['visitr_5060_rat'] = df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
df['visitr_70_rat'] = df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']

df['tar_num_rat'] = (df['tar_num'] )/(df['tar_num'].mean()) #지역별총자원수/107개평균

df['fore_popl_rat'] = df['fore_popl_num']/df['popl_num_2023_10']

#연령대비_방문자비율
df['visitr_mz_rat'] = (df['male_twnes_visitr_rat']+df['fmale_twnes_visitr_rat']+df['male_thrtes_visitr_rat']+df['fmale_thrtes_visitr_rat']) / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 2030 방문자 비율 

df['visitr_flower_rat'] = (df['fmale_fortes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_fites_visitr_rat']+df['male_fites_visitr_rat']) / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 5060 방문자 비율 

#방문객 대비 업종별 카드소비액
df['lodg_tou_rat'] = df['lodg_tob_card_compt_amt']/df['sgg_tou_num'] #숙박업소비/방문객수
df['tour_tou_rat'] = df['tour_tob_card_compt_amt']/df['sgg_tou_num']#여행업소비/방문객수
df['trs_tou_rat'] = df['trs_tob_card_compt_amt']/df['sgg_tou_num']#운송업소비/방문객수
df['shpn_tou_rat'] = df['shpn_tob_card_compt_amt']/df['sgg_tou_num']#쇼핑업소비/방문객수
df['sptm_tou_rat'] = df['sptm_svc_tob_rela_card_compt_amt']/df['sgg_tou_num']#여가서비스업소비/방문객수
df['food_drk_tou_rat'] = df['food_drk_tob_rela_card_compt_amt']/df['sgg_tou_num']#식음료업소비/방문객수

#업종별카드소비액/업종별카드소비금액합 
df['compt_mat5']=df['lodg_tob_card_compt_amt']+df['tour_tob_card_compt_amt']+ df['shpn_tob_card_compt_amt']+df['sptm_svc_tob_rela_card_compt_amt']+ df['food_drk_tob_rela_card_compt_amt']
df['lodg_comp_rat_5'] = df['lodg_tob_card_compt_amt']/df['compt_mat5']
df['tour_comp_rat_5'] = df['tour_tob_card_compt_amt']/df['compt_mat5']
df['shpn_comp_rat_5'] = df['shpn_tob_card_compt_amt']/df['compt_mat5']
df['sptm_comp_rat_5'] = df['sptm_svc_tob_rela_card_compt_amt']/df['compt_mat5']
df['food_drk_comp_rat_5'] = df['food_drk_tob_rela_card_compt_amt']/df['compt_mat5']

df['sns_tou_rat']=df['sns_mm_avg_cnt']/df['sgg_tou_num']      #총언급량/방문객수

#성연령별 비율 시군구단위 재집계
df['male_10_rat'] = df['male_tens_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성10대
df['male_20_rat'] = df['male_twnes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성20대 
df['male_30_rat'] = df['male_thrtes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성30대 
df['male_40_rat'] = df['male_fortes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성40대 
df['male_50_rat'] = df['male_fites_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성50대 
df['male_60_rat'] = df['male_sxtes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성60대 
df['male_70_rat'] = df['male_sevnes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 남성70대 

df['fmale_10_rat'] = df['fmale_tens_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성10대
df['fmale_20_rat'] = df['fmale_twnes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성20대 
df['fmale_30_rat'] = df['fmale_thrtes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성30대 
df['fmale_40_rat'] = df['fmale_fortes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성40대 
df['fmale_50_rat'] = df['fmale_fites_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성50대 
df['fmale_60_rat'] = df['fmale_sxtes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성60대 
df['fmale_70_rat'] = df['fmale_sevnes_visitr_rat'] / (df['male_tens_visitr_rat']+df['male_twnes_visitr_rat']+df['fmale_tens_visitr_rat']+df['fmale_twnes_visitr_rat']
                        +df['male_thrtes_visitr_rat']+df['male_fortes_visitr_rat']+df['fmale_thrtes_visitr_rat']+df['fmale_fortes_visitr_rat']
                        +df['male_fites_visitr_rat']+df['male_sxtes_visitr_rat']+df['fmale_fites_visitr_rat']+df['fmale_sxtes_visitr_rat']
                        +df['male_sevnes_visitr_rat']+df['fmale_sevnes_visitr_rat']) # 전체연령대비 여성70대

# %%
df.to_csv('LPA_data_output_1201_total.csv', index=False, encoding="CP949")

# %%
df_output_1201=  df[['sgg_cd'	
    ,'popl_tou_rat'	
    ,'visitr_mz_rat'
    ,'dstnc_tou_rat'
    ,'compt_GRDP_rat'
    ,'AVG_STAY_TM'	
    ,'AVG_LODG_DAYS'	
    ,'tar_num_rat'	
    ,'biz_turs_rat'	
    ,'sgg_tursm_bdgt'	
    ,'socty_corpo_rat'	
    ,'INFO_CNT_RAT'
    ,'TRAD_COMT_RAT'	
    ,'CAR_RAT'	
    ,'ct_tour_rat'
    ,'sns_mm_avg_cnt']]
df_output_1201.to_csv('LPA_data_output_1201_test07.csv', index=False, encoding="CP949")
